# %%
# %pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp312-cp312-macosx_12_0_arm64.whl.metadata (31 kB)
# Requirement already satisfied: numpy>=1.19.5 in /opt/anaconda3/envs/datajournal/lib/python3.12/site-packages (from scikit-learn) (2.2.3)
# Requirement already satisfied: scipy>=1.6.0 in /opt/anaconda3/envs/datajournal/lib/python3.12/site-packages (from scikit-learn) (1.15.2)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp312-cp312-macosx_12_0_arm64.whl (11.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 28.7 MB/s eta 0:00:00 0:00:01
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.6.1 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("gapminder.csv").dropna()
data.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
continent = pd.get_dummies(data['continent'], drop_first = True).astype(int)
data = pd.concat([data, continent], axis = 1)
data.head()
# Out:
#        country continent  year  lifeExp  ...  Americas  Asia  Europe  Oceania
# 0  Afghanistan      Asia  1952   28.801  ...         0     1       0        0
# 1  Afghanistan      Asia  1957   30.332  ...         0     1       0        0
# 2  Afghanistan      Asia  1962   31.997  ...         0     1       0        0
# 3  Afghanistan      Asia  1967   34.020  ...         0     1       0        0
# 4  Afghanistan      Asia  1972   36.088  ...         0     1       0        0
#
# [5 rows x 10 columns]

# %%
inputs = ['pop', 'gdpPercap', 'year', 'Americas', 'Asia', 'Europe', 'Oceania']
data[inputs].corr()
# Out:
#                 pop  gdpPercap  ...        Europe       Oceania
# pop        1.000000  -0.025600  ... -6.062454e-02 -2.334280e-02
# gdpPercap -0.025600   1.000000  ...  3.809787e-01  1.383432e-01
# year       0.082308   0.227318  ...  2.118443e-15 -6.039044e-15
# Americas  -0.022198  -0.003716  ... -2.392372e-01 -5.524946e-02
# Asia       0.245947   0.038349  ... -2.847707e-01 -6.576498e-02
# Europe    -0.060625   0.380979  ...  1.000000e+00 -6.185896e-02
# Oceania   -0.023343   0.138343  ... -6.185896e-02  1.000000e+00
#
# [7 rows x 7 columns]

# %%
train, test = train_test_split(data, test_size = 0.3, random_state = 2024)

# %%
model = sm.OLS(train['lifeExp'], train[inputs]).fit()

# %%
sns.scatterplot(y=train['lifeExp'], x=model.predict(train[inputs]))
plt.xlabel("predicted")
plt.ylabel("actual")
# Out:
# Text(0, 0.5, 'actual')

# %%
residuals = train['lifeExp'] - model.predict(train[inputs])
sns.scatterplot(y=residuals, x=model.predict(train[inputs]))
plt.xlabel("predicted")
plt.ylabel("residuals")
# Out:
# Text(0, 0.5, 'residuals')

# %%
residuals = train['lifeExp'] - model.predict(train[inputs])
sns.scatterplot(y=residuals, x=train['gdpPercap'])
# Out:
# <Axes: xlabel='gdpPercap', ylabel='None'>

# %%
sns.scatterplot(y=train['lifeExp'], x=np.log(train['gdpPercap']))
# Out:
# <Axes: xlabel='gdpPercap', ylabel='lifeExp'>

# %%
data['gdpPercap'] = np.log(data['gdpPercap'])
data['pop'] = np.log(data['pop'])

data['year'] = data['year'] - 1952

# %%
train, test = train_test_split(data, test_size = 0.3, random_state = 2024)

# %%
model = sm.OLS(train['lifeExp'],train[inputs]).fit()

residuals = train['lifeExp'] - model.predict(train[inputs])
sns.scatterplot(x=model.predict(train[inputs]),y=residuals)
plt.xlabel('Predicted')
plt.ylabel('Residual')
plt.show()

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_true=train['lifeExp'], y_pred=model.predict(train[inputs]))
# Out:
# 4.3298825740521165

# %%
mean_absolute_error(y_true=test['lifeExp'], y_pred=model.predict(test[inputs]))
# Out:
# 4.535159622012662

# %%
print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                lifeExp   R-squared (uncentered):                   0.991
# Model:                            OLS   Adj. R-squared (uncentered):              0.991
# Method:                 Least Squares   F-statistic:                          1.932e+04
# Date:                Thu, 13 Mar 2025   Prob (F-statistic):                        0.00
# Time:                        18:05:09   Log-Likelihood:                         -3760.6
# No. Observations:                1192   AIC:                                      7535.
# Df Residuals:                    1185   BIC:                                      7571.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# pop           -5.0033      0.652     -7.673      0.000      -6.283      -3.724
# gdpPercap     82.1297      2.641     31.098      0.000      76.948      87.311
# year           0.2571      0.010     26.312      0.000       0.238       0.276
# Americas       8.6768      0.525     16.517      0.000       7.646       9.708
# Asia           7.2904      0.448     16.279      0.000       6.412       8.169
# Europe        12.6628      0.546     23.205      0.000      11.592      13.733
# Oceania       13.5938      1.589      8.555      0.000      10.476      16.711
# ==============================================================================
# Omnibus:                       60.407   Durbin-Watson:                   2.020
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               72.280
# Skew:                          -0.518   Prob(JB):                     2.02e-16
# Kurtosis:                       3.617   Cond. No.                         549.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sns.scatterplot(y=train['lifeExp'], x=model.predict(train[inputs]))
plt.xlabel("predicted")
plt.ylabel("actual")
# Out:
# Text(0, 0.5, 'actual')
